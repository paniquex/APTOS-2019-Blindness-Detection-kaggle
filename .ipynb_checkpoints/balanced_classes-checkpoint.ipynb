# %%
import pandas as pd
import numpy as np

# %%
train_new_csv = pd.read_csv('./input/train_new.csv')
train_old_csv = pd.read_csv('./input/train_old.csv')
test_old_csv = pd.read_csv('./input/test_old.csv')
test_old_csv.drop(['Usage'], axis=1, inplace=True)
test_old_csv.columns = ['id_code', 'diagnosis']

test_old_full = pd.concat([train_old_csv, test_old_csv])

train_mixed_csv = pd.concat([train_new_csv, train_old_csv, test_old_csv])

# %%
test_old_csv
# Out:
#            id_code  diagnosis
# 0           1_left          0
# 1          1_right          0
# 2           2_left          0
# 3          2_right          0
# 4           3_left          2
# 5          3_right          2
# 6           4_left          2
# 7          4_right          2
# 8           5_left          0
# 9          5_right          0
# 10          6_left          1
# 11         6_right          1
# 12          7_left          0
# 13         7_right          0
# 14          8_left          2
# 15         8_right          2
# 16          9_left          4
# 17         9_right          4
# 18         11_left          0
# 19        11_right          0
# 20         12_left          0
# 21        12_right          0
# 22         14_left          0
# 23        14_right          0
# 24         18_left          0
# 25        18_right          0
# 26         24_left          0
# 27        24_right          0
# 28         26_left          0
# 29        26_right          0
# ...            ...        ...
# 53546   44324_left          0
# 53547  44324_right          0
# 53548   44326_left          0
# 53549  44326_right          0
# 53550   44329_left          1
# 53551  44329_right          1
# 53552   44332_left          0
# 53553  44332_right          0
# 53554   44333_left          3
# 53555  44333_right          3
# 53556   44335_left          0
# 53557  44335_right          0
# 53558   44336_left          0
# 53559  44336_right          0
# 53560   44340_left          0
# 53561  44340_right          0
# 53562   44341_left          0
# 53563  44341_right          0
# 53564   44342_left          0
# 53565  44342_right          0
# 53566   44344_left          0
# 53567  44344_right          2
# 53568   44345_left          0
# 53569  44345_right          1
# 53570   44346_left          0
# 53571  44346_right          0
# 53572   44350_left          0
# 53573  44350_right          0
# 53574   44351_left          0
# 53575  44351_right          0
#
# [53576 rows x 2 columns]

# %%
train_old_csv = pd.concat([train_old_csv, test_old_csv])

# %%
train_mixed_csv['diagnosis'].value_counts()
# Out:
# 0    67148
# 2    14152
# 1     6575
# 3     2280
# 4     2209
# Name: diagnosis, dtype: int64

# %%
train_balanced_csv = pd.DataFrame(columns=['id_code', 'diagnosis'])
train_balanced_csv.append(pd.Series(), ignore_index=True)
samples_per_class = 2209
diagnosis_list = range(5)
for diag in diagnosis_list:
    if len(train_new_csv[train_new_csv['diagnosis'] == diag]) >= samples_per_class:
        train_balanced_csv = pd.concat(
            [train_balanced_csv, train_new_csv[train_new_csv['diagnosis'] == diag].sample(samples_per_class)]
        )
    else:
        new_len = len(train_new_csv[train_new_csv['diagnosis'] == diag])
        train_balanced_csv = pd.concat(
            [train_balanced_csv, train_new_csv[train_new_csv['diagnosis'] == diag].sample(new_len),
            train_old_csv[train_old_csv['diagnosis'] == diag].sample(samples_per_class-new_len)]
        )

# %%
train_balanced_csv['diagnosis'].value_counts()
# Out:
# 4    2209
# 3    2209
# 2    2209
# 1    2209
# 0    2209
# Name: diagnosis, dtype: int64

# %%
train_balanced_csv.to_csv('./input/train_balanced.csv')
